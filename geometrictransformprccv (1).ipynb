# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

#Load image
image = cv2.imread('image1.jpg')
#Get image dimension
height, width = image.shape[:2]

#display original image
plt.figure(figsize=(6,6))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
plt.show()

#define translation matrix
translation_matrix = np.float32([[1, 0, 50], [0, 1, 10]])

#Apply translation matrix
translated_image = cv2.warpAffine(image, translation_matrix, (width, height))

#Display translated image
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(translated_image, cv2.COLOR_BGR2RGB))
plt.title('Translated Image')
plt.axis('off')
plt.show()

#Define rotation matrix
rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), 60, 1)

#Apply rotation
rotated_image =  cv2.warpAffine(image, rotation_matrix, (width, height))

#display rotated image
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB))
plt.title('Rotated Image')
plt.axis('off')
plt.show()

#Define scaling matrix
scaling_matrix = np.float32([[0.8, 0, 0],[0, 0.8, 0]])

#APPLY SCALING MATRRIX
scaled_image = cv2.warpAffine(image, scaling_matrix,(int(width*0.5), int(height*0.5)))

#Define scaling image
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(scaled_image, cv2.COLOR_BGR2RGB))
plt.title('Scaled Image')
plt.axis('off')
plt.show()


#Define afdfline transformation points
original_points = np.float32(([50,50], [200,50], [100,250]))
transformed_points = np.float32([[10,100], [200, 50], [100, 250]])

#Compute affline transformation points
original_points = np.float32(([50,50], [200,50], [100,250]))
transformed_points = np.float32([[10,100], [200, 50], [100, 250]])

#affline transformation matrix
affine_matrix =cv2.getAffineTransform(original_points, transformed_points)

#affline transformation
affine_transformed_image = cv2.warpAffine(image, affine_matrix, (width, height))
#Define scaling image
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(affine_transformed_image, cv2.COLOR_BGR2RGB))
plt.title('Affine Transformed Image')
plt.axis('off')
plt.show()

#Define  perspective transformation points
original_points = np.float32([[56,65], [368, 52],[28, 387],[389, 390]])
transformed_points = np.float32([[0, 0], [300, 0], [300, 300],[300, 300]])

#apply perspective transformation
perspective_matrix = cv2.getPerspectiveTransform(original_points, transformed_points)

perspective_transformed_image = cv2.warpPerspectiveTransform(image, perspective_matrix, (width,height))
#apply perspective transformation
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(perspective_transformed_image, cv2.COLOR_BGR2RGB))
plt.title('Perspective Transformed Image')
plt.axis('off')
plt.show()
print("Gayatri Kulkarni -53004230002")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-cd5fab06aae4> in <module>
# ----> 1 import cv2
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4
#       5 #Load image
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install opencv-python
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
# ...
#   Running setup.py bdist_wheel for opencv-python: started
#   Running setup.py bdist_wheel for opencv-python: finished with status 'error'
#   Complete output from command D:\Anaconda\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\GAYATR~1\\AppData\\Local\\Temp\\pip-install-p2iy9x2j\\opencv-python\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\GAYATR~1\AppData\Local\Temp\pip-wheel-eq2d1ijr --python-tag cp37:
#
#
#   --------------------------------------------------------------------------------
#   -- Trying 'Ninja (Visual Studio 17 2022 x64 v144)' generator
#   --------------------------------
#   ---------------------------
#   ----------------------
#   -----------------
#   ------------
#   -------
#   --
# ...
